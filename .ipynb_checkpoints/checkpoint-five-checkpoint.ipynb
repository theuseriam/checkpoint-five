# %% [markdown]
# # Checkpoint Five: Modeling Data
#
# With your visualizations ready to go, the final step in your project is to do some predictive analysis on your dataset. You will be using linear regression for your model. You will not be penalized if your linear regression model does not work out. You just need to build the model and make notes as to the results.
#
# Link to my dataset:
#
# ## Prepare Your Dataframe
#
# Import any libraries you need and create a dataframe.

# %%
# import the pandas library and use the alias 'pd', I am also importing seaborn matplot and numpy for visualizations
import pandas as pd

import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')

from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (16,8)

pd.options.mode.chained_assignment = None

# Create 3 new dataframes

#NAICS = pd.read_csv('KS 2020-2021 NAICS Code.csv')
#KS_tax = pd.read_csv('KS 2021 Sales Tax Revenue by County.csv')
national = pd.read_csv('selected-monthly-sales-tax-collections-data.csv')
NAKES = pd.read_csv('NAICS_cleaned.csv')
KS_taxes = pd.read_csv('Clean_KS_tax.csv')

# %%
#verifying the cleaned csv file is pulling in
NAKES.describe()
# Out:
#        Unnamed: 0    November20    November21  FY21_Percent_Change  \
# count  105.000000  1.050000e+02  1.050000e+02           105.000000
# mean    72.552381  1.653894e+06  2.242569e+06            40.456190
# std     43.118125  6.276202e+06  8.516351e+06            62.919631
# min      2.000000  3.635500e+02  7.930700e+02           -64.000000
# 25%     36.000000  4.739029e+04  6.651045e+04             3.900000
# 50%     66.000000  2.145329e+05  2.679732e+05            21.400000
# 75%    109.000000  7.061781e+05  8.163617e+05            51.300000
# max    152.000000  5.792842e+07  7.853589e+07           247.700000
#
#        FY21_July-Nov_20  Fy22_July-November21  FY22_Percent_Change
# count      1.050000e+02          1.050000e+02           105.000000
# mean       8.079968e+06          1.017890e+07            28.560000
# std        3.058217e+07          3.829049e+07            42.476486
# min        2.341080e+03          5.669490e+03           -37.700000
# 25%        2.543019e+05          4.510708e+05             2.700000
# 50%        1.073556e+06          1.286237e+06            18.000000
# 75%        3.861625e+06          3.701161e+06            43.100000
# max        2.829773e+08          3.564667e+08           162.100000

# %%
# #Even though it was previously deleted, the Unnamed: 0 column is pulling in so I am dropping it
NAKES = NAKES.drop(['Unnamed: 0'], axis=1)
                              
NAKES.head()
NAKES.describe()
# Out:
#          November20    November21  FY21_Percent_Change  FY21_July-Nov_20  \
# count  1.050000e+02  1.050000e+02           105.000000      1.050000e+02
# mean   1.653894e+06  2.242569e+06            40.456190      8.079968e+06
# std    6.276202e+06  8.516351e+06            62.919631      3.058217e+07
# min    3.635500e+02  7.930700e+02           -64.000000      2.341080e+03
# 25%    4.739029e+04  6.651045e+04             3.900000      2.543019e+05
# 50%    2.145329e+05  2.679732e+05            21.400000      1.073556e+06
# 75%    7.061781e+05  8.163617e+05            51.300000      3.861625e+06
# max    5.792842e+07  7.853589e+07           247.700000      2.829773e+08
#
#        Fy22_July-November21  FY22_Percent_Change
# count          1.050000e+02           105.000000
# mean           1.017890e+07            28.560000
# std            3.829049e+07            42.476486
# min            5.669490e+03           -37.700000
# 25%            4.510708e+05             2.700000
# 50%            1.286237e+06            18.000000
# 75%            3.701161e+06            43.100000
# max            3.564667e+08           162.100000

# %%
#verifying the cleaned CSV file is pulling in
Cleaned_KS.describe()
# Out:
# count  4.040000e+02  4.060000e+02  4.060000e+02    4.060000e+02  4.050000e+02
# mean   4.794900e+05  4.757566e+05  4.606778e+05    4.880801e+05  4.665355e+05
# std    4.878461e+06  4.855289e+06  4.698003e+06    4.981141e+06  4.762448e+06
# min    1.041000e+01  1.900000e-01  6.420000e+00    4.060000e+00  8.000000e-02
# 25%    4.983475e+03  5.131757e+03  4.717030e+03    5.350175e+03  4.832700e+03
# 50%    2.332819e+04  2.171336e+04  2.212490e+04    2.349285e+04  2.308555e+04
# 75%    1.070239e+05  1.056828e+05  1.011402e+05    1.076931e+05  1.004741e+05
# max    9.594438e+07  9.565948e+07  9.263738e+07    9.813828e+07  9.364158e+07
#
#        November 2021  December 2021      CY Total
# count   4.040000e+02   4.030000e+02  4.060000e+02
# mean    4.149194e+05   5.662165e+05  5.485233e+06
# std     4.216780e+06   5.756921e+06  5.594649e+07
# min     4.770000e+00   1.048100e+02  6.699200e+02
# 25%     4.576198e+03   5.828715e+03  5.992993e+04
# 50%     1.973442e+04   2.687616e+04  2.682392e+05
# 75%     9.204391e+04   1.220679e+05  1.209876e+06
# max     8.304026e+07   1.130296e+08  1.102975e+09

# %%
national.head()
national.describe()
# Out:
#                Year        Amount    FIPS State  Numeric Month
# count  11781.000000  9.162000e+03  11781.000000   11781.000000
# mean    2020.090909  2.826828e+08     28.960784       6.909091
# std        0.792561  8.800411e+08     15.677501       3.306366
# min     2019.000000 -2.174000e+08      1.000000       1.000000
# 25%     2019.000000  1.029016e+07     16.000000       4.000000
# 50%     2020.000000  4.892506e+07     29.000000       7.000000
# 75%     2021.000000  2.369788e+08     42.000000      10.000000
# max     2021.000000  2.425489e+10     56.000000      12.000000

# %% [markdown]
# ## Find Correlations
#
# Use either pairplot or a heatmap or both to find the two variables with the strongest correlation in your dataset.

# %%
# Using pairplot to visualize the data for correlation


plt.tight_layout() # sizes are overlapping so I am runnig this so I can see them
plt.figure(figsize = (16,90))



sns.pairplot(Cleaned_KS, x_vars=[ 'CY Total'], 
             y_vars='City/County', height=4, aspect=1, kind='scatter')

plt.tick_params(axis='x', which='major', labelsize=3)

plt.show()

# %%
# Visualizing the state data using a heatmap
plt.figure(figsize = (16,8))
sns.heatmap(national.corr(), cmap="inferno_r", annot = True)
# Out:
# <AxesSubplot:>

# %%
try:
    sns.heatmap(NAKES.corr(), cmap='inferno_r', annot = True)
except ValueError:
    pass

# %%
# Visualizing the state data using a heatmap
plt.figure(figsize = (16,8))
sns.heatmap(Cleaned_KS.corr(), cmap="twilight", annot = True)
# Out:
# <AxesSubplot:>

# %%
# Using pairplot to visualize the data for correlation

# %% [markdown]
# ## Create Your Model
#
# Use the two columns with the strongest correlation to create and train your model. Make sure to print out the summary and plot the column values and the line produced by the model.

# %% [markdown]
# ## Error Terms
#
# Finally, plot your error terms!

# %% [markdown]
# ## Summarize Your Work
#
# Make notes of your answers to the questions below.
#
# 1. What was your R-squared value? 0.638
# 2. Based on your results, do you think a linear regression model was the best type of predictive analysis for your dataset? It was not particularly effective in this case.
# 3. Was your plot of the error terms a bell curve? Not really
