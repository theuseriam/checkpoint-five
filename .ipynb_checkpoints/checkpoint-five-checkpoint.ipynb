# %% [markdown]
# # Checkpoint Five: Modeling Data
#
# With your visualizations ready to go, the final step in your project is to do some predictive analysis on your dataset. You will be using linear regression for your model. You will not be penalized if your linear regression model does not work out. You just need to build the model and make notes as to the results.
#
# Link to my dataset:
#
# ## Prepare Your Dataframe
#
# Import any libraries you need and create a dataframe.

# %%
# import the pandas library and use the alias 'pd', I am also importing seaborn matplot and numpy for visualizations
import pandas as pd

import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')

from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (16,8)

pd.options.mode.chained_assignment = None

# Create 3 new dataframes

NAICS = pd.read_csv('NAICS_cleaned.csv')
KS_tax = pd.read_csv('Clean_KS_tax.csv')
national = pd.read_csv('selected-monthly-sales-tax-collections-data.csv')

# %%
NAICS = NAICS.drop(['Unnamed: 0'], axis=1)
NAICS.head()
# Out:
#                                    Industry Totals  Locations  November 2020  \
# 0                              111 Crop Production         10     $4,745.95
# 1                            112 Animal Production         11     $6,351.24
# 2  115 Agriculture and Forestry Support Activities          6    $10,419.29
# 3                                           Totals         27    $21,516.48
# 4                       211 Oil and Gas Extraction         12    $31,555.14
#
#   November 2021 FY 21Percent Change FY 21 July-Nov 2020  \
# 0    $7,097.19                49.5%         $25,549.22
# 1    $2,284.42               -64.0%         $34,045.34
# 2   $21,398.96               105.4%         $87,421.06
# 3   $30,780.57                43.1%        $147,015.62
# 4   $66,510.45               110.8%        $205,669.20
#
#   Fy 22 July-November 2021 FY22 Percent Change
# 0              $39,066.06                52.9%
# 1              $31,309.63                -8.0%
# ...

# %%
KS_tax = KS_tax.drop(['Unnamed: 0', 'Unnamed: 13'], axis=1)
KS_tax.head()
# Out:
#          City/County   January 2021  February 2021     March 2021  \
# 0      Allen County    $179,656.95    $198,296.15    $198,852.35
# 1   Anderson County     $99,419.17    $107,801.82     $92,757.01
# 2   Atchison County    $185,101.29    $215,743.10    $205,204.58
# 3     Barber County     $50,604.13     $52,913.17     $48,676.21
# 4     Barton County    $367,322.15    $423,958.68    $392,671.82
#
#       April 2021       May 2021      June 2021      July 2021    August 2021  \
# 0   $170,017.20    $220,698.15    $233,208.62    $207,534.60    $222,248.65
# 1    $96,370.25    $122,369.53    $126,893.61    $114,436.59    $116,107.46
# 2   $197,686.55    $221,956.34    $229,019.17    $211,991.30    $214,438.53
# 3    $51,192.55     $58,379.28     $62,516.17     $54,357.94     $53,762.62
# 4   $348,589.39    $447,790.31    $475,422.65    $426,024.48    $437,259.74
#
#   September 2021   October 2021  November 2021  December 2021         CY Total
# ...

# %%
national.head()
# Out:
#       Name Collection Month  Year            Tax Type       Amount  \
# 0  Alabama            April  2019  Alcoholic Beverage          NaN
# 1  Alabama            April  2019    Corporate Income  175385574.0
# 2  Alabama            April  2019       General Sales  277352000.0
# 3  Alabama            April  2019   Individual Income  532804493.0
# 4  Alabama            April  2019             Lodging    7589968.0
#
#    FIPS State  Numeric Month
# 0           1              4
# 1           1              4
# 2           1              4
# 3           1              4
# 4           1              4

# %% [markdown]
# ## Find Correlations
#
# Use either pairplot or a heatmap or both to find the two variables with the strongest correlation in your dataset.

# %%
# Using pairplot to visualize the data for correlation

plt.figure(figsize = (175,160))
sns.pairplot(KS_tax, x_vars=['City/County', 'CY Total'], 
             y_vars='December 2021', height=4, aspect=1, kind='scatter')
plt.show()

# %%
# Visualizing the state data using a heatmap
sns.heatmap(national.corr(), cmap="inferno_r", annot = True)
# Out:
# <AxesSubplot:>

# %%
try:
    sns.heatmap(KS_tax.corr(), cmap='inferno_r', annot = True)
except ValueError:
    pass

# %%
# Using pairplot to visualize the data for correlation

plt.figure(figsize = (195,180))
sns.pairplot(NAICS, x_vars=['FY 21 July-Nov 2020','Fy 22 July-November 2021'], 
             y_vars='Industry Totals', height=4, aspect=1, kind='scatter')
plt.show()

# %% [markdown]
# ## Create Your Model
#
# Use the two columns with the strongest correlation to create and train your model. Make sure to print out the summary and plot the column values and the line produced by the model.

# %% [markdown]
# ## Error Terms
#
# Finally, plot your error terms!

# %% [markdown]
# ## Summarize Your Work
#
# Make notes of your answers to the questions below.
#
# 1. What was your R-squared value? 0.638
# 2. Based on your results, do you think a linear regression model was the best type of predictive analysis for your dataset? It was not particularly effective in this case.
# 3. Was your plot of the error terms a bell curve? Not really
