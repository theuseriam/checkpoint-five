# %% [markdown]
# # Checkpoint Five: Modeling Data
#
# With your visualizations ready to go, the final step in your project is to do some predictive analysis on your dataset. You will be using linear regression for your model. You will not be penalized if your linear regression model does not work out. You just need to build the model and make notes as to the results.
#
# Link to my dataset:
#
# ## Prepare Your Dataframe
#
# Import any libraries you need and create a dataframe.

# %%
# import the pandas library and use the alias 'pd', I am also importing seaborn matplot and numpy for visualizations
import pandas as pd

import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')

from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# Create 3 new dataframes

NAICS = pd.read_csv('NAICS_clean.csv')
KS_tax = pd.read_csv('Clean_KS_tax.csv')
national = pd.read_csv('selected-monthly-sales-tax-collections-data.csv')

# %% [markdown]
# ## Find Correlations
#
# Use either pairplot or a heatmap or both to find the two variables with the strongest correlation in your dataset.

# %%
# Using pairplot we'll visualize the data for correlation
sns.pairplot(KS_tax, x_vars=['City/County', 'CY Total'], 
             y_vars='December 2021', height=4, aspect=1, kind='scatter')
plt.show()

# %%
# Visualizing the state data using a heatmap
sns.heatmap(national.corr(), cmap="twilight_r", annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(NAICS.corr(), cmap='inferno_r', annot = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <module>
# ----> 1 sns.heatmap(NAICS.corr(), cmap='inferno_r', annot = True)
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:535, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     357 """Plot rectangular data as a color-encoded matrix.
#     358
#     359 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     532     ...     ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)
#     533 """
#     534 # Initialize the plotter object
# --> 535 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     536                       annot_kws, cbar, cbar_kws, xticklabels,
#     537                       yticklabels, mask)
#     539 # Add the pcolormesh kwargs here
#     540 kwargs["linewidths"] = linewidths
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:155, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     152 self.ylabel = ylabel if ylabel is not None else ""
#     154 # Determine good default values for the colormapping
# --> 155 self._determine_cmap_params(plot_data, vmin, vmax,
#     156                             cmap, center, robust)
#     158 # Sort out the annotations
#     159 if annot is None or annot is False:
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:194, in _HeatMapper._determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     192         vmin = np.nanpercentile(calc_data, 2)
#     193     else:
# --> 194         vmin = np.nanmin(calc_data)
#     195 if vmax is None:
#     196     if robust:
#
# File <__array_function__ internals>:5, in nanmin(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:319, in nanmin(a, axis, out, keepdims)
#     315     kwargs['keepdims'] = keepdims
#     316 if type(a) is np.ndarray and a.dtype != np.object_:
#     317     # Fast, but not safe for subclasses of ndarray, or object arrays,
#     318     # which do not implement isnan (gh-9009), or fmin correctly (gh-8975)
# --> 319     res = np.fmin.reduce(a, axis=axis, out=out, **kwargs)
#     320     if np.isnan(res).any():
#     321         warnings.warn("All-NaN slice encountered", RuntimeWarning,
#     322                       stacklevel=3)
#
# ValueError: zero-size array to reduction operation fmin which has no identity

# %% [markdown]
# ## Create Your Model
#
# Use the two columns with the strongest correlation to create and train your model. Make sure to print out the summary and plot the column values and the line produced by the model.

# %% [markdown]
# ## Error Terms
#
# Finally, plot your error terms!

# %% [markdown]
# ## Summarize Your Work
#
# Make notes of your answers to the questions below.
#
# 1. What was your R-squared value? 0.638
# 2. Based on your results, do you think a linear regression model was the best type of predictive analysis for your dataset? It was not particularly effective in this case.
# 3. Was your plot of the error terms a bell curve? Not really
